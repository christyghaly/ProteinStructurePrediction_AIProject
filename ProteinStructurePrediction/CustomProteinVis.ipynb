# %%
conda install -c omnia -c conda-forge openmm
# Out:
# Collecting package metadata (current_repodata.json): ...working... done
# Solving environment: ...working... done
#
# ## Package Plan ##
#
#   environment location: C:\Users\hp\anaconda3
#
#   added / updated specs:
#     - openmm
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     cudatoolkit-11.2.1         |       h7a7aa70_8       880.7 MB  conda-forge
#     fftw-3.3.9                 |nompi_hd3ad3c4_101         744 KB  conda-forge
#     khronos-opencl-icd-loader-2020.12.18|       h8d14728_0          69 KB  conda-forge
#     openmm-7.5.0               |   py38h206f027_6        10.3 MB  conda-forge
#     ------------------------------------------------------------
#                                            Total:       891.7 MB
#
# The following NEW packages will be INSTALLED:
#
#   cudatoolkit        conda-forge/win-64::cudatoolkit-11.2.1-h7a7aa70_8
#   fftw               conda-forge/win-64::fftw-3.3.9-nompi_hd3ad3c4_101
#   khronos-opencl-ic~ conda-forge/win-64::khronos-opencl-icd-loader-2020.12.18-h8d14728_0
#   openmm             conda-forge/win-64::openmm-7.5.0-py38h206f027_6
#
#
#
# Note: you may need to restart the kernel to use updated packages.
# WARNING conda.gateways.disk.delete:unlink_or_rename_to_trash(139): Could not remove or rename C:\Users\hp\anaconda3\pkgs\cudatoolkit-11.2.1-h7a7aa70_8\Library\bin\cusolverMg64_11.dll.  Please remove this file manually (you may need to reboot to free file handles)
# WARNING conda.gateways.disk.delete:unlink_or_rename_to_trash(139): Could not remove or rename C:\Users\hp\anaconda3\pkgs\cudatoolkit-11.2.1-h7a7aa70_8\Library\bin\cublasLt64_11.dll.  Please remove this file manually (you may need to reboot to free file handles)
# WARNING conda.gateways.disk.delete:unlink_or_rename_to_trash(139): Could not remove or rename C:\Users\hp\anaconda3\pkgs\cudatoolkit-11.2.1-h7a7aa70_8\Library\bin\cusolverMg64_11.dll.  Please remove this file manually (you may need to reboot to free file handles)
#
# InvalidArchiveError('Error with archive C:\\Users\\hp\\anaconda3\\pkgs\\cudatoolkit-11.2.1-h7a7aa70_8.tar.bz2.  You probably need to delete and re-download or re-create this file.  Message from libarchive was:\n\nbzip decompression failed')
# Downloading and Extracting Packages
#
# khronos-opencl-icd-l | 69 KB     |            |   0%
# khronos-opencl-icd-l | 69 KB     | ##3        |  23%
# khronos-opencl-icd-l | 69 KB     | ########## | 100%
# khronos-opencl-icd-l | 69 KB     | ########## | 100%
#
# openmm-7.5.0         | 10.3 MB   |            |   0%
# openmm-7.5.0         | 10.3 MB   |            |   0%
# openmm-7.5.0         | 10.3 MB   | 1          |   1%
# openmm-7.5.0         | 10.3 MB   | 2          |   3%
# openmm-7.5.0         | 10.3 MB   | 3          |   4%
# openmm-7.5.0         | 10.3 MB   | 6          |   6%
# openmm-7.5.0         | 10.3 MB   | 9          |   9%
# openmm-7.5.0         | 10.3 MB   | #3         |  14%
# openmm-7.5.0         | 10.3 MB   | #9         |  19%
# openmm-7.5.0         | 10.3 MB   | ##4        |  24%
# openmm-7.5.0         | 10.3 MB   | ##6        |  26%
# openmm-7.5.0         | 10.3 MB   | ##9        |  29%
# openmm-7.5.0         | 10.3 MB   | ###1       |  32%
# openmm-7.5.0         | 10.3 MB   | ###3       |  34%
# openmm-7.5.0         | 10.3 MB   | ###5       |  36%
# openmm-7.5.0         | 10.3 MB   | ###7       |  38%
# openmm-7.5.0         | 10.3 MB   | ####2      |  42%
# openmm-7.5.0         | 10.3 MB   | ####5      |  46%
# openmm-7.5.0         | 10.3 MB   | #####1     |  51%
# openmm-7.5.0         | 10.3 MB   | #####3     |  54%
# openmm-7.5.0         | 10.3 MB   | #####6     |  56%
# openmm-7.5.0         | 10.3 MB   | #####9     |  59%
# openmm-7.5.0         | 10.3 MB   | ######3    |  63%
# openmm-7.5.0         | 10.3 MB   | ######7    |  67%
# openmm-7.5.0         | 10.3 MB   | #######    |  71%
# openmm-7.5.0         | 10.3 MB   | #######2   |  72%
# openmm-7.5.0         | 10.3 MB   | #######9   |  80%
# openmm-7.5.0         | 10.3 MB   | ########4  |  85%
# openmm-7.5.0         | 10.3 MB   | ########7  |  88%
# openmm-7.5.0         | 10.3 MB   | #########1 |  92%
# openmm-7.5.0         | 10.3 MB   | #########3 |  93%
# openmm-7.5.0         | 10.3 MB   | #########7 |  98%
# openmm-7.5.0         | 10.3 MB   | ########## | 100%
# openmm-7.5.0         | 10.3 MB   | ########## | 100%
#
# fftw-3.3.9           | 744 KB    |            |   0%
# fftw-3.3.9           | 744 KB    | 2          |   2%
# fftw-3.3.9           | 744 KB    | ##7        |  28%
# fftw-3.3.9           | 744 KB    | ###8       |  39%
# fftw-3.3.9           | 744 KB    | ######6    |  67%
# fftw-3.3.9           | 744 KB    | ########## | 100%
# fftw-3.3.9           | 744 KB    | ########## | 100%
#
# cudatoolkit-11.2.1   | 880.7 MB  |            |   0%
# cudatoolkit-11.2.1   | 880.7 MB  |            |   0%
# cudatoolkit-11.2.1   | 880.7 MB  |            |   0%
# cudatoolkit-11.2.1   | 880.7 MB  |            |   0%
# cudatoolkit-11.2.1   | 880.7 MB  |            |   0%
# cudatoolkit-11.2.1   | 880.7 MB  |            |   0%
# cudatoolkit-11.2.1   | 880.7 MB  |            |   0%
# cudatoolkit-11.2.1   | 880.7 MB  |            |   0%
# cudatoolkit-11.2.1   | 880.7 MB  |            |   0%
# cudatoolkit-11.2.1   | 880.7 MB  |            |   0%
# cudatoolkit-11.2.1   | 880.7 MB  |            |   0%
# cudatoolkit-11.2.1   | 880.7 MB  |            |   0%
# cudatoolkit-11.2.1   | 880.7 MB  |            |   0%
# cudatoolkit-11.2.1   | 880.7 MB  |            |   0%
# cudatoolkit-11.2.1   | 880.7 MB  |            |   0%
# cudatoolkit-11.2.1   | 880.7 MB  |            |   0%
# cudatoolkit-11.2.1   | 880.7 MB  |            |   1%
# cudatoolkit-11.2.1   | 880.7 MB  |            |   1%
# cudatoolkit-11.2.1   | 880.7 MB  |            |   1%
# cudatoolkit-11.2.1   | 880.7 MB  |            |   1%
# cudatoolkit-11.2.1   | 880.7 MB  |            |   1%
# cudatoolkit-11.2.1   | 880.7 MB  |            |   1%
# cudatoolkit-11.2.1   | 880.7 MB  |            |   1%
# cudatoolkit-11.2.1   | 880.7 MB  |            |   1%
# cudatoolkit-11.2.1   | 880.7 MB  |            |   1%
# cudatoolkit-11.2.1   | 880.7 MB  |            |   1%
# cudatoolkit-11.2.1   | 880.7 MB  |            |   1%
# cudatoolkit-11.2.1   | 880.7 MB  |            |   1%
# cudatoolkit-11.2.1   | 880.7 MB  |            |   1%
# cudatoolkit-11.2.1   | 880.7 MB  | 1          |   1%
# cudatoolkit-11.2.1   | 880.7 MB  | 1          |   1%
# cudatoolkit-11.2.1   | 880.7 MB  | 1          |   1%
# cudatoolkit-11.2.1   | 880.7 MB  | 1          |   1%
# cudatoolkit-11.2.1   | 880.7 MB  | 1          |   1%
# cudatoolkit-11.2.1   | 880.7 MB  | 1          |   1%
# cudatoolkit-11.2.1   | 880.7 MB  | 1          |   1%
# cudatoolkit-11.2.1   | 880.7 MB  | 1          |   1%
# cudatoolkit-11.2.1   | 880.7 MB  | 1          |   1%
# cudatoolkit-11.2.1   | 880.7 MB  | 1          |   1%
# cudatoolkit-11.2.1   | 880.7 MB  | 1          |   1%
# cudatoolkit-11.2.1   | 880.7 MB  | 1          |   1%
# cudatoolkit-11.2.1   | 880.7 MB  | 1          |   1%
# cudatoolkit-11.2.1   | 880.7 MB  | 1          |   2%
# cudatoolkit-11.2.1   | 880.7 MB  | 1          |   2%
# cudatoolkit-11.2.1   | 880.7 MB  | 1          |   2%
# cudatoolkit-11.2.1   | 880.7 MB  | 1          |   2%
# cudatoolkit-11.2.1   | 880.7 MB  | 1          |   2%
# cudatoolkit-11.2.1   | 880.7 MB  | 1          |   2%
# cudatoolkit-11.2.1   | 880.7 MB  | 1          |   2%
# cudatoolkit-11.2.1   | 880.7 MB  | 1          |   2%
# cudatoolkit-11.2.1   | 880.7 MB  | 1          |   2%
# cudatoolkit-11.2.1   | 880.7 MB  | 1          |   2%
# cudatoolkit-11.2.1   | 880.7 MB  | 1          |   2%
# cudatoolkit-11.2.1   | 880.7 MB  | 1          |   2%
# cudatoolkit-11.2.1   | 880.7 MB  | 1          |   2%
# cudatoolkit-11.2.1   | 880.7 MB  | 1          |   2%
# cudatoolkit-11.2.1   | 880.7 MB  | 1          |   2%
# cudatoolkit-11.2.1   | 880.7 MB  | 2          |   2%
# cudatoolkit-11.2.1   | 880.7 MB  | 2          |   2%
# cudatoolkit-11.2.1   | 880.7 MB  | 2          |   2%
# cudatoolkit-11.2.1   | 880.7 MB  | 2          |   2%
# cudatoolkit-11.2.1   | 880.7 MB  | 2          |   2%
# cudatoolkit-11.2.1   | 880.7 MB  | 2          |   2%
# cudatoolkit-11.2.1   | 880.7 MB  | 2          |   2%
# cudatoolkit-11.2.1   | 880.7 MB  | 2          |   2%
# cudatoolkit-11.2.1   | 880.7 MB  | 2          |   2%
# cudatoolkit-11.2.1   | 880.7 MB  | 2          |   2%
# cudatoolkit-11.2.1   | 880.7 MB  | 2          |   2%
# cudatoolkit-11.2.1   | 880.7 MB  | 2          |   2%
# cudatoolkit-11.2.1   | 880.7 MB  | 2          |   2%
# cudatoolkit-11.2.1   | 880.7 MB  | 2          |   2%
# cudatoolkit-11.2.1   | 880.7 MB  | 2          |   2%
# cudatoolkit-11.2.1   | 880.7 MB  | 2          |   3%
# cudatoolkit-11.2.1   | 880.7 MB  | 2          |   3%
# cudatoolkit-11.2.1   | 880.7 MB  | 2          |   3%
# cudatoolkit-11.2.1   | 880.7 MB  | 2          |   3%
# cudatoolkit-11.2.1   | 880.7 MB  | 2          |   3%
# cudatoolkit-11.2.1   | 880.7 MB  | 2          |   3%
# cudatoolkit-11.2.1   | 880.7 MB  | 2          |   3%
# cudatoolkit-11.2.1   | 880.7 MB  | 2          |   3%
# cudatoolkit-11.2.1   | 880.7 MB  | 2          |   3%
# cudatoolkit-11.2.1   | 880.7 MB  | 2          |   3%
# cudatoolkit-11.2.1   | 880.7 MB  | 2          |   3%
# cudatoolkit-11.2.1   | 880.7 MB  | 2          |   3%
# cudatoolkit-11.2.1   | 880.7 MB  | 2          |   3%
# cudatoolkit-11.2.1   | 880.7 MB  | 2          |   3%
# cudatoolkit-11.2.1   | 880.7 MB  | 2          |   3%
# cudatoolkit-11.2.1   | 880.7 MB  | 2          |   3%
# cudatoolkit-11.2.1   | 880.7 MB  | 2          |   3%
# cudatoolkit-11.2.1   | 880.7 MB  | 3          |   3%
# cudatoolkit-11.2.1   | 880.7 MB  | 3          |   3%
# cudatoolkit-11.2.1   | 880.7 MB  | 3          |   3%
# cudatoolkit-11.2.1   | 880.7 MB  | 3          |   3%
# cudatoolkit-11.2.1   | 880.7 MB  | 3          |   3%
# cudatoolkit-11.2.1   | 880.7 MB  | 3          |   3%
# cudatoolkit-11.2.1   | 880.7 MB  | 3          |   3%
# cudatoolkit-11.2.1   | 880.7 MB  | 3          |   3%
# cudatoolkit-11.2.1   | 880.7 MB  | 3          |   3%
# cudatoolkit-11.2.1   | 880.7 MB  | 3          |   3%
# cudatoolkit-11.2.1   | 880.7 MB  | 3          |   3%
# cudatoolkit-11.2.1   | 880.7 MB  | 3          |   3%
# cudatoolkit-11.2.1   | 880.7 MB  | 3          |   3%
# cudatoolkit-11.2.1   | 880.7 MB  | 3          |   3%
# cudatoolkit-11.2.1   | 880.7 MB  | 3          |   3%
# cudatoolkit-11.2.1   | 880.7 MB  | 3          |   3%
# cudatoolkit-11.2.1   | 880.7 MB  | 3          |   3%
# cudatoolkit-11.2.1   | 880.7 MB  | 3          |   3%
# cudatoolkit-11.2.1   | 880.7 MB  | 3          |   3%
# cudatoolkit-11.2.1   | 880.7 MB  | 3          |   4%
# cudatoolkit-11.2.1   | 880.7 MB  | 3          |   4%
# cudatoolkit-11.2.1   | 880.7 MB  | 3          |   4%
# cudatoolkit-11.2.1   | 880.7 MB  | 3          |   4%
# cudatoolkit-11.2.1   | 880.7 MB  | 3          |   4%
# cudatoolkit-11.2.1   | 880.7 MB  | 3          |   4%
# cudatoolkit-11.2.1   | 880.7 MB  | 3          |   4%
# cudatoolkit-11.2.1   | 880.7 MB  | 3          |   4%
# cudatoolkit-11.2.1   | 880.7 MB  | 3          |   4%
# cudatoolkit-11.2.1   | 880.7 MB  | 3          |   4%
# cudatoolkit-11.2.1   | 880.7 MB  | 3          |   4%
# cudatoolkit-11.2.1   | 880.7 MB  | 3          |   4%
# cudatoolkit-11.2.1   | 880.7 MB  | 3          |   4%
# cudatoolkit-11.2.1   | 880.7 MB  | 3          |   4%
# cudatoolkit-11.2.1   | 880.7 MB  | 3          |   4%
# cudatoolkit-11.2.1   | 880.7 MB  | 3          |   4%
# cudatoolkit-11.2.1   | 880.7 MB  | 3          |   4%
# cudatoolkit-11.2.1   | 880.7 MB  | 4          |   4%
# cudatoolkit-11.2.1   | 880.7 MB  | 4          |   4%
# cudatoolkit-11.2.1   | 880.7 MB  | 4          |   4%
# cudatoolkit-11.2.1   | 880.7 MB  | 4          |   4%
# cudatoolkit-11.2.1   | 880.7 MB  | 4          |   4%
# cudatoolkit-11.2.1   | 880.7 MB  | 4          |   4%
# cudatoolkit-11.2.1   | 880.7 MB  | 4          |   4%
# cudatoolkit-11.2.1   | 880.7 MB  | 4          |   4%
# cudatoolkit-11.2.1   | 880.7 MB  | 4          |   4%
# cudatoolkit-11.2.1   | 880.7 MB  | 4          |   4%
# cudatoolkit-11.2.1   | 880.7 MB  | 4          |   4%
# cudatoolkit-11.2.1   | 880.7 MB  | 4          |   4%
# cudatoolkit-11.2.1   | 880.7 MB  | 4          |   4%
# cudatoolkit-11.2.1   | 880.7 MB  | 4          |   5%
# cudatoolkit-11.2.1   | 880.7 MB  | 4          |   5%
# cudatoolkit-11.2.1   | 880.7 MB  | 4          |   5%
# cudatoolkit-11.2.1   | 880.7 MB  | 4          |   5%
# cudatoolkit-11.2.1   | 880.7 MB  | 4          |   5%
# cudatoolkit-11.2.1   | 880.7 MB  | 4          |   5%
# cudatoolkit-11.2.1   | 880.7 MB  | 4          |   5%
# cudatoolkit-11.2.1   | 880.7 MB  | 4          |   5%
# cudatoolkit-11.2.1   | 880.7 MB  | 4          |   5%
# cudatoolkit-11.2.1   | 880.7 MB  | 4          |   5%
# cudatoolkit-11.2.1   | 880.7 MB  | 4          |   5%
# cudatoolkit-11.2.1   | 880.7 MB  | 4          |   5%
# cudatoolkit-11.2.1   | 880.7 MB  | 4          |   5%
# cudatoolkit-11.2.1   | 880.7 MB  | 4          |   5%
# cudatoolkit-11.2.1   | 880.7 MB  | 5          |   5%
# cudatoolkit-11.2.1   | 880.7 MB  | 5          |   5%
# cudatoolkit-11.2.1   | 880.7 MB  | 5          |   5%
# cudatoolkit-11.2.1   | 880.7 MB  | 5          |   5%
# cudatoolkit-11.2.1   | 880.7 MB  | 5          |   5%
# cudatoolkit-11.2.1   | 880.7 MB  | 5          |   5%
# cudatoolkit-11.2.1   | 880.7 MB  | 5          |   5%
# cudatoolkit-11.2.1   | 880.7 MB  | 5          |   5%
# cudatoolkit-11.2.1   | 880.7 MB  | 5          |   5%
# cudatoolkit-11.2.1   | 880.7 MB  | 5          |   5%
# cudatoolkit-11.2.1   | 880.7 MB  | 5          |   5%
# cudatoolkit-11.2.1   | 880.7 MB  | 5          |   6%
# cudatoolkit-11.2.1   | 880.7 MB  | 5          |   6%
# cudatoolkit-11.2.1   | 880.7 MB  | 5          |   6%
# cudatoolkit-11.2.1   | 880.7 MB  | 5          |   6%
# cudatoolkit-11.2.1   | 880.7 MB  | 5          |   6%
# cudatoolkit-11.2.1   | 880.7 MB  | 5          |   6%
# cudatoolkit-11.2.1   | 880.7 MB  | 5          |   6%
# cudatoolkit-11.2.1   | 880.7 MB  | 5          |   6%
# cudatoolkit-11.2.1   | 880.7 MB  | 5          |   6%
# cudatoolkit-11.2.1   | 880.7 MB  | 5          |   6%
# cudatoolkit-11.2.1   | 880.7 MB  | 5          |   6%
# cudatoolkit-11.2.1   | 880.7 MB  | 5          |   6%
# cudatoolkit-11.2.1   | 880.7 MB  | 5          |   6%
# cudatoolkit-11.2.1   | 880.7 MB  | 5          |   6%
# cudatoolkit-11.2.1   | 880.7 MB  | 5          |   6%
# cudatoolkit-11.2.1   | 880.7 MB  | 5          |   6%
# cudatoolkit-11.2.1   | 880.7 MB  | 5          |   6%
# cudatoolkit-11.2.1   | 880.7 MB  | 6          |   6%
# cudatoolkit-11.2.1   | 880.7 MB  | 6          |   6%
# cudatoolkit-11.2.1   | 880.7 MB  | 6          |   6%
# cudatoolkit-11.2.1   | 880.7 MB  | 6          |   6%
# cudatoolkit-11.2.1   | 880.7 MB  | 6          |   6%
# cudatoolkit-11.2.1   | 880.7 MB  | 6          |   6%
# cudatoolkit-11.2.1   | 880.7 MB  | 6          |   6%
# cudatoolkit-11.2.1   | 880.7 MB  | 6          |   6%
# cudatoolkit-11.2.1   | 880.7 MB  | 6          |   6%
# cudatoolkit-11.2.1   | 880.7 MB  | 6          |   6%
# cudatoolkit-11.2.1   | 880.7 MB  | 6          |   6%
# cudatoolkit-11.2.1   | 880.7 MB  | 6          |   6%
# cudatoolkit-11.2.1   | 880.7 MB  | 6          |   6%
# cudatoolkit-11.2.1   | 880.7 MB  | 6          |   6%
# cudatoolkit-11.2.1   | 880.7 MB  | 6          |   6%
# cudatoolkit-11.2.1   | 880.7 MB  | 6          |   7%
# cudatoolkit-11.2.1   | 880.7 MB  | 6          |   7%
# cudatoolkit-11.2.1   | 880.7 MB  | 6          |   7%
# cudatoolkit-11.2.1   | 880.7 MB  | 6          |   7%
# cudatoolkit-11.2.1   | 880.7 MB  | 6          |   7%
# cudatoolkit-11.2.1   | 880.7 MB  | 6          |   7%
# cudatoolkit-11.2.1   | 880.7 MB  | 6          |   7%
# cudatoolkit-11.2.1   | 880.7 MB  | 6          |   7%
# cudatoolkit-11.2.1   | 880.7 MB  | 6          |   7%
# cudatoolkit-11.2.1   | 880.7 MB  | 6          |   7%
# cudatoolkit-11.2.1   | 880.7 MB  | 6          |   7%
# cudatoolkit-11.2.1   | 880.7 MB  | 6          |   7%
# cudatoolkit-11.2.1   | 880.7 MB  | 6          |   7%
# cudatoolkit-11.2.1   | 880.7 MB  | 6          |   7%
# cudatoolkit-11.2.1   | 880.7 MB  | 7          |   7%
# cudatoolkit-11.2.1   | 880.7 MB  | 7          |   7%
# cudatoolkit-11.2.1   | 880.7 MB  | 7          |   7%
# cudatoolkit-11.2.1   | 880.7 MB  | 7          |   7%
# cudatoolkit-11.2.1   | 880.7 MB  | 7          |   7%
# cudatoolkit-11.2.1   | 880.7 MB  | 7          |   7%
# cudatoolkit-11.2.1   | 880.7 MB  | 7          |   7%
# cudatoolkit-11.2.1   | 880.7 MB  | 7          |   7%
# cudatoolkit-11.2.1   | 880.7 MB  | 7          |   7%
# cudatoolkit-11.2.1   | 880.7 MB  | 7          |   7%
# cudatoolkit-11.2.1   | 880.7 MB  | 7          |   7%
# cudatoolkit-11.2.1   | 880.7 MB  | 7          |   7%
# cudatoolkit-11.2.1   | 880.7 MB  | 7          |   7%
# cudatoolkit-11.2.1   | 880.7 MB  | 7          |   7%
# cudatoolkit-11.2.1   | 880.7 MB  | 7          |   8%
# cudatoolkit-11.2.1   | 880.7 MB  | 7          |   8%
# cudatoolkit-11.2.1   | 880.7 MB  | 7          |   8%
# cudatoolkit-11.2.1   | 880.7 MB  | 7          |   8%
# cudatoolkit-11.2.1   | 880.7 MB  | 7          |   8%
# cudatoolkit-11.2.1   | 880.7 MB  | 7          |   8%
# cudatoolkit-11.2.1   | 880.7 MB  | 7          |   8%
# cudatoolkit-11.2.1   | 880.7 MB  | 7          |   8%
# cudatoolkit-11.2.1   | 880.7 MB  | 7          |   8%
# cudatoolkit-11.2.1   | 880.7 MB  | 7          |   8%
# cudatoolkit-11.2.1   | 880.7 MB  | 7          |   8%
# cudatoolkit-11.2.1   | 880.7 MB  | 7          |   8%
# cudatoolkit-11.2.1   | 880.7 MB  | 7          |   8%
# cudatoolkit-11.2.1   | 880.7 MB  | 7          |   8%
# cudatoolkit-11.2.1   | 880.7 MB  | 7          |   8%
# cudatoolkit-11.2.1   | 880.7 MB  | 7          |   8%
# cudatoolkit-11.2.1   | 880.7 MB  | 8          |   8%
# cudatoolkit-11.2.1   | 880.7 MB  | 8          |   8%
# cudatoolkit-11.2.1   | 880.7 MB  | 8          |   8%
# cudatoolkit-11.2.1   | 880.7 MB  | 8          |   8%
# cudatoolkit-11.2.1   | 880.7 MB  | 8          |   8%
# cudatoolkit-11.2.1   | 880.7 MB  | 8          |   8%
# cudatoolkit-11.2.1   | 880.7 MB  | 8          |   8%
# cudatoolkit-11.2.1   | 880.7 MB  | 8          |   8%
# cudatoolkit-11.2.1   | 880.7 MB  | 8          |   8%
# cudatoolkit-11.2.1   | 880.7 MB  | 8          |   8%
# cudatoolkit-11.2.1   | 880.7 MB  | 8          |   8%
# cudatoolkit-11.2.1   | 880.7 MB  | 8          |   8%
# cudatoolkit-11.2.1   | 880.7 MB  | 8          |   9%
# cudatoolkit-11.2.1   | 880.7 MB  | 8          |   9%
# cudatoolkit-11.2.1   | 880.7 MB  | 8          |   9%
# cudatoolkit-11.2.1   | 880.7 MB  | 8          |   9%
# cudatoolkit-11.2.1   | 880.7 MB  | 8          |   9%
# cudatoolkit-11.2.1   | 880.7 MB  | 8          |   9%
# cudatoolkit-11.2.1   | 880.7 MB  | 8          |   9%
# cudatoolkit-11.2.1   | 880.7 MB  | 8          |   9%
# cudatoolkit-11.2.1   | 880.7 MB  | 8          |   9%
# cudatoolkit-11.2.1   | 880.7 MB  | 8          |   9%
# cudatoolkit-11.2.1   | 880.7 MB  | 8          |   9%
# cudatoolkit-11.2.1   | 880.7 MB  | 8          |   9%
# cudatoolkit-11.2.1   | 880.7 MB  | 8          |   9%
# cudatoolkit-11.2.1   | 880.7 MB  | 9          |   9%
# cudatoolkit-11.2.1   | 880.7 MB  | 9          |   9%
# cudatoolkit-11.2.1   | 880.7 MB  | 9          |   9%
# cudatoolkit-11.2.1   | 880.7 MB  | 9          |   9%
# cudatoolkit-11.2.1   | 880.7 MB  | 9          |   9%
# cudatoolkit-11.2.1   | 880.7 MB  | 9          |   9%
# cudatoolkit-11.2.1   | 880.7 MB  | 9          |   9%
# cudatoolkit-11.2.1   | 880.7 MB  | 9          |   9%
# cudatoolkit-11.2.1   | 880.7 MB  | 9          |   9%
# cudatoolkit-11.2.1   | 880.7 MB  | 9          |   9%
# cudatoolkit-11.2.1   | 880.7 MB  | 9          |   9%
# cudatoolkit-11.2.1   | 880.7 MB  | 9          |   9%
# cudatoolkit-11.2.1   | 880.7 MB  | 9          |   9%
# cudatoolkit-11.2.1   | 880.7 MB  | 9          |   9%
# cudatoolkit-11.2.1   | 880.7 MB  | 9          |   9%
# cudatoolkit-11.2.1   | 880.7 MB  | 9          |  10%
# cudatoolkit-11.2.1   | 880.7 MB  | 9          |  10%
# cudatoolkit-11.2.1   | 880.7 MB  | 9          |  10%
# cudatoolkit-11.2.1   | 880.7 MB  | 9          |  10%
# cudatoolkit-11.2.1   | 880.7 MB  | 9          |  10%
# cudatoolkit-11.2.1   | 880.7 MB  | 9          |  10%
# cudatoolkit-11.2.1   | 880.7 MB  | 9          |  10%
# cudatoolkit-11.2.1   | 880.7 MB  | 9          |  10%
# cudatoolkit-11.2.1   | 880.7 MB  | 9          |  10%
# cudatoolkit-11.2.1   | 880.7 MB  | 9          |  10%
# cudatoolkit-11.2.1   | 880.7 MB  | 9          |  10%
# cudatoolkit-11.2.1   | 880.7 MB  | 9          |  10%
# cudatoolkit-11.2.1   | 880.7 MB  | 9          |  10%
# cudatoolkit-11.2.1   | 880.7 MB  | #          |  10%
# cudatoolkit-11.2.1   | 880.7 MB  | #          |  10%
# cudatoolkit-11.2.1   | 880.7 MB  | #          |  10%
# cudatoolkit-11.2.1   | 880.7 MB  | #          |  10%
# cudatoolkit-11.2.1   | 880.7 MB  | #          |  10%
# cudatoolkit-11.2.1   | 880.7 MB  | #          |  10%
# cudatoolkit-11.2.1   | 880.7 MB  | #          |  10%
# cudatoolkit-11.2.1   | 880.7 MB  | #          |  10%
# cudatoolkit-11.2.1   | 880.7 MB  | #          |  10%
# cudatoolkit-11.2.1   | 880.7 MB  | #          |  10%
# cudatoolkit-11.2.1   | 880.7 MB  | #          |  10%
# cudatoolkit-11.2.1   | 880.7 MB  | #          |  10%
# cudatoolkit-11.2.1   | 880.7 MB  | #          |  10%
# cudatoolkit-11.2.1   | 880.7 MB  | #          |  10%
# cudatoolkit-11.2.1   | 880.7 MB  | #          |  10%
# cudatoolkit-11.2.1   | 880.7 MB  | #          |  11%
# cudatoolkit-11.2.1   | 880.7 MB  | #          |  11%
# cudatoolkit-11.2.1   | 880.7 MB  | #          |  11%
# cudatoolkit-11.2.1   | 880.7 MB  | #          |  11%
# cudatoolkit-11.2.1   | 880.7 MB  | #          |  11%
# cudatoolkit-11.2.1   | 880.7 MB  | #          |  11%
# cudatoolkit-11.2.1   | 880.7 MB  | #          |  11%
# cudatoolkit-11.2.1   | 880.7 MB  | #          |  11%
# cudatoolkit-11.2.1   | 880.7 MB  | #          |  11%
# cudatoolkit-11.2.1   | 880.7 MB  | #          |  11%
# cudatoolkit-11.2.1   | 880.7 MB  | #          |  11%
# cudatoolkit-11.2.1   | 880.7 MB  | #          |  11%
# cudatoolkit-11.2.1   | 880.7 MB  | #          |  11%
# cudatoolkit-11.2.1   | 880.7 MB  | #          |  11%
# cudatoolkit-11.2.1   | 880.7 MB  | #1         |  11%
# cudatoolkit-11.2.1   | 880.7 MB  | #1         |  11%
# cudatoolkit-11.2.1   | 880.7 MB  | #1         |  11%
# cudatoolkit-11.2.1   | 880.7 MB  | #1         |  11%
# cudatoolkit-11.2.1   | 880.7 MB  | #1         |  11%
# cudatoolkit-11.2.1   | 880.7 MB  | #1         |  11%
# cudatoolkit-11.2.1   | 880.7 MB  | #1         |  11%
# cudatoolkit-11.2.1   | 880.7 MB  | #1         |  11%
# cudatoolkit-11.2.1   | 880.7 MB  | #1         |  11%
# cudatoolkit-11.2.1   | 880.7 MB  | #1         |  11%
# cudatoolkit-11.2.1   | 880.7 MB  | #1         |  11%
# cudatoolkit-11.2.1   | 880.7 MB  | #1         |  11%
# cudatoolkit-11.2.1   | 880.7 MB  | #1         |  11%
# cudatoolkit-11.2.1   | 880.7 MB  | #1         |  11%
# cudatoolkit-11.2.1   | 880.7 MB  | #1         |  11%
# cudatoolkit-11.2.1   | 880.7 MB  | #1         |  11%
# cudatoolkit-11.2.1   | 880.7 MB  | #1         |  11%
# cudatoolkit-11.2.1   | 880.7 MB  | #1         |  11%
# cudatoolkit-11.2.1   | 880.7 MB  | #1         |  11%
# cudatoolkit-11.2.1   | 880.7 MB  | #1         |  11%
# cudatoolkit-11.2.1   | 880.7 MB  | #1         |  11%
# cudatoolkit-11.2.1   | 880.7 MB  | #1         |  11%
# cudatoolkit-11.2.1   | 880.7 MB  | #1         |  11%
# cudatoolkit-11.2.1   | 880.7 MB  | #1         |  11%
# cudatoolkit-11.2.1   | 880.7 MB  | #1         |  11%
# cudatoolkit-11.2.1   | 880.7 MB  | #1         |  11%
# cudatoolkit-11.2.1   | 880.7 MB  | #1         |  12%
# cudatoolkit-11.2.1   | 880.7 MB  | #1         |  12%
# cudatoolkit-11.2.1   | 880.7 MB  | #1         |  12%
# cudatoolkit-11.2.1   | 880.7 MB  | #1         |  12%
# cudatoolkit-11.2.1   | 880.7 MB  | #1         |  12%
# cudatoolkit-11.2.1   | 880.7 MB  | #1         |  12%
# cudatoolkit-11.2.1   | 880.7 MB  | #1         |  12%
# cudatoolkit-11.2.1   | 880.7 MB  | #1         |  12%
# cudatoolkit-11.2.1   | 880.7 MB  | #1         |  12%
# cudatoolkit-11.2.1   | 880.7 MB  | #1         |  12%
# cudatoolkit-11.2.1   | 880.7 MB  | #1         |  12%
# cudatoolkit-11.2.1   | 880.7 MB  | #1         |  12%
# cudatoolkit-11.2.1   | 880.7 MB  | #1         |  12%
# cudatoolkit-11.2.1   | 880.7 MB  | #1         |  12%
# cudatoolkit-11.2.1   | 880.7 MB  | #1         |  12%
# cudatoolkit-11.2.1   | 880.7 MB  | #1         |  12%
# cudatoolkit-11.2.1   | 880.7 MB  | #1         |  12%
# cudatoolkit-11.2.1   | 880.7 MB  | #1         |  12%
# cudatoolkit-11.2.1   | 880.7 MB  | #1         |  12%
# cudatoolkit-11.2.1   | 880.7 MB  | #1         |  12%
# cudatoolkit-11.2.1   | 880.7 MB  | #1         |  12%
# cudatoolkit-11.2.1   | 880.7 MB  | #1         |  12%
# cudatoolkit-11.2.1   | 880.7 MB  | #1         |  12%
# cudatoolkit-11.2.1   | 880.7 MB  | #1         |  12%
# cudatoolkit-11.2.1   | 880.7 MB  | #1         |  12%
# cudatoolkit-11.2.1   | 880.7 MB  | #1         |  12%
# cudatoolkit-11.2.1   | 880.7 MB  | #1         |  12%
# cudatoolkit-11.2.1   | 880.7 MB  | #1         |  12%
# cudatoolkit-11.2.1   | 880.7 MB  | #1         |  12%
# cudatoolkit-11.2.1   | 880.7 MB  | #1         |  12%
# cudatoolkit-11.2.1   | 880.7 MB  | #1         |  12%
# cudatoolkit-11.2.1   | 880.7 MB  | #1         |  12%
# cudatoolkit-11.2.1   | 880.7 MB  | #1         |  12%
# cudatoolkit-11.2.1   | 880.7 MB  | #1         |  12%
# cudatoolkit-11.2.1   | 880.7 MB  | #1         |  12%
# cudatoolkit-11.2.1   | 880.7 MB  | #1         |  12%
# cudatoolkit-11.2.1   | 880.7 MB  | #1         |  12%
# cudatoolkit-11.2.1   | 880.7 MB  | #1         |  12%
# cudatoolkit-11.2.1   | 880.7 MB  | #1         |  12%
# cudatoolkit-11.2.1   | 880.7 MB  | #1         |  12%
# cudatoolkit-11.2.1   | 880.7 MB  | #1         |  12%
# cudatoolkit-11.2.1   | 880.7 MB  | #1         |  12%
# cudatoolkit-11.2.1   | 880.7 MB  | #1         |  12%
# cudatoolkit-11.2.1   | 880.7 MB  | #1         |  12%
# cudatoolkit-11.2.1   | 880.7 MB  | #1         |  12%
# cudatoolkit-11.2.1   | 880.7 MB  | #1         |  12%
# cudatoolkit-11.2.1   | 880.7 MB  | #1         |  12%
# cudatoolkit-11.2.1   | 880.7 MB  | #1         |  12%
# cudatoolkit-11.2.1   | 880.7 MB  | #1         |  12%
# cudatoolkit-11.2.1   | 880.7 MB  | #1         |  12%
# cudatoolkit-11.2.1   | 880.7 MB  | #1         |  12%
# cudatoolkit-11.2.1   | 880.7 MB  | #1         |  12%
# cudatoolkit-11.2.1   | 880.7 MB  | #1         |  12%
# cudatoolkit-11.2.1   | 880.7 MB  | #1         |  12%
# cudatoolkit-11.2.1   | 880.7 MB  | #1         |  12%
# cudatoolkit-11.2.1   | 880.7 MB  | #1         |  12%
# cudatoolkit-11.2.1   | 880.7 MB  | #1         |  12%
# cudatoolkit-11.2.1   | 880.7 MB  | #1         |  12%
# cudatoolkit-11.2.1   | 880.7 MB  | #1         |  12%
# cudatoolkit-11.2.1   | 880.7 MB  | #1         |  12%
# cudatoolkit-11.2.1   | 880.7 MB  | #1         |  12%
# cudatoolkit-11.2.1   | 880.7 MB  | #1         |  12%
# cudatoolkit-11.2.1   | 880.7 MB  | #1         |  12%
# cudatoolkit-11.2.1   | 880.7 MB  | #1         |  12%
# cudatoolkit-11.2.1   | 880.7 MB  | #1         |  12%
# cudatoolkit-11.2.1   | 880.7 MB  | #1         |  12%
# cudatoolkit-11.2.1   | 880.7 MB  | #1         |  12%
# cudatoolkit-11.2.1   | 880.7 MB  | #1         |  12%
# cudatoolkit-11.2.1   | 880.7 MB  | #1         |  12%
# cudatoolkit-11.2.1   | 880.7 MB  | #2         |  12%
# cudatoolkit-11.2.1   | 880.7 MB  | #2         |  12%
# cudatoolkit-11.2.1   | 880.7 MB  | #2         |  12%
# cudatoolkit-11.2.1   | 880.7 MB  | #2         |  12%
# cudatoolkit-11.2.1   | 880.7 MB  | #2         |  12%
# cudatoolkit-11.2.1   | 880.7 MB  | #2         |  12%
# cudatoolkit-11.2.1   | 880.7 MB  | #2         |  12%
# cudatoolkit-11.2.1   | 880.7 MB  | #2         |  12%
# cudatoolkit-11.2.1   | 880.7 MB  | #2         |  12%
# cudatoolkit-11.2.1   | 880.7 MB  | #2         |  12%
# cudatoolkit-11.2.1   | 880.7 MB  | #2         |  12%
# cudatoolkit-11.2.1   | 880.7 MB  | #2         |  12%
# cudatoolkit-11.2.1   | 880.7 MB  | #2         |  12%
# cudatoolkit-11.2.1   | 880.7 MB  | #2         |  12%
# cudatoolkit-11.2.1   | 880.7 MB  | #2         |  12%
# cudatoolkit-11.2.1   | 880.7 MB  | #2         |  12%
# cudatoolkit-11.2.1   | 880.7 MB  | #2         |  12%
# cudatoolkit-11.2.1   | 880.7 MB  | #2         |  12%
# cudatoolkit-11.2.1   | 880.7 MB  | #2         |  12%
# cudatoolkit-11.2.1   | 880.7 MB  | #2         |  12%
# cudatoolkit-11.2.1   | 880.7 MB  | #2         |  12%
# cudatoolkit-11.2.1   | 880.7 MB  | #2         |  13%
# cudatoolkit-11.2.1   | 880.7 MB  | #2         |  13%
# cudatoolkit-11.2.1   | 880.7 MB  | #2         |  13%
# cudatoolkit-11.2.1   | 880.7 MB  | #2         |  13%
# cudatoolkit-11.2.1   | 880.7 MB  | #2         |  13%
# cudatoolkit-11.2.1   | 880.7 MB  | #2         |  13%
# cudatoolkit-11.2.1   | 880.7 MB  | #2         |  13%
# cudatoolkit-11.2.1   | 880.7 MB  | #2         |  13%
# cudatoolkit-11.2.1   | 880.7 MB  | #2         |  13%
# cudatoolkit-11.2.1   | 880.7 MB  | #2         |  13%
# cudatoolkit-11.2.1   | 880.7 MB  | #2         |  13%
# cudatoolkit-11.2.1   | 880.7 MB  | #2         |  13%
# cudatoolkit-11.2.1   | 880.7 MB  | #2         |  13%
# cudatoolkit-11.2.1   | 880.7 MB  | #2         |  13%
# cudatoolkit-11.2.1   | 880.7 MB  | #2         |  13%
# cudatoolkit-11.2.1   | 880.7 MB  | #2         |  13%
# cudatoolkit-11.2.1   | 880.7 MB  | #2         |  13%
# cudatoolkit-11.2.1   | 880.7 MB  | #3         |  13%
# cudatoolkit-11.2.1   | 880.7 MB  | #3         |  13%
# cudatoolkit-11.2.1   | 880.7 MB  | #3         |  13%
# cudatoolkit-11.2.1   | 880.7 MB  | #3         |  13%
# cudatoolkit-11.2.1   | 880.7 MB  | #3         |  13%
# cudatoolkit-11.2.1   | 880.7 MB  | #3         |  13%
# cudatoolkit-11.2.1   | 880.7 MB  | #3         |  13%
# cudatoolkit-11.2.1   | 880.7 MB  | #3         |  13%
# cudatoolkit-11.2.1   | 880.7 MB  | #3         |  13%
# cudatoolkit-11.2.1   | 880.7 MB  | #3         |  13%
# cudatoolkit-11.2.1   | 880.7 MB  | #3         |  13%
# cudatoolkit-11.2.1   | 880.7 MB  | #3         |  13%
# cudatoolkit-11.2.1   | 880.7 MB  | #3         |  14%
# cudatoolkit-11.2.1   | 880.7 MB  | #3         |  14%
# cudatoolkit-11.2.1   | 880.7 MB  | #3         |  14%
# cudatoolkit-11.2.1   | 880.7 MB  | #3         |  14%
# cudatoolkit-11.2.1   | 880.7 MB  | #3         |  14%
# cudatoolkit-11.2.1   | 880.7 MB  | #3         |  14%
# cudatoolkit-11.2.1   | 880.7 MB  | #3         |  14%
# cudatoolkit-11.2.1   | 880.7 MB  | #3         |  14%
# cudatoolkit-11.2.1   | 880.7 MB  | #3         |  14%
# cudatoolkit-11.2.1   | 880.7 MB  | #3         |  14%
# cudatoolkit-11.2.1   | 880.7 MB  | #3         |  14%
# cudatoolkit-11.2.1   | 880.7 MB  | #3         |  14%
# cudatoolkit-11.2.1   | 880.7 MB  | #3         |  14%
# cudatoolkit-11.2.1   | 880.7 MB  | #4         |  14%
# cudatoolkit-11.2.1   | 880.7 MB  | #4         |  14%
# cudatoolkit-11.2.1   | 880.7 MB  | #4         |  14%
# cudatoolkit-11.2.1   | 880.7 MB  | #4         |  14%
# cudatoolkit-11.2.1   | 880.7 MB  | #4         |  14%
# cudatoolkit-11.2.1   | 880.7 MB  | #4         |  14%
# cudatoolkit-11.2.1   | 880.7 MB  | #4         |  14%
# cudatoolkit-11.2.1   | 880.7 MB  | #4         |  14%
# cudatoolkit-11.2.1   | 880.7 MB  | #4         |  14%
# cudatoolkit-11.2.1   | 880.7 MB  | #4         |  14%
# cudatoolkit-11.2.1   | 880.7 MB  | #4         |  14%
# cudatoolkit-11.2.1   | 880.7 MB  | #4         |  14%
# cudatoolkit-11.2.1   | 880.7 MB  | #4         |  14%
# cudatoolkit-11.2.1   | 880.7 MB  | #4         |  14%
# cudatoolkit-11.2.1   | 880.7 MB  | #4         |  14%
# cudatoolkit-11.2.1   | 880.7 MB  | #4         |  14%
# cudatoolkit-11.2.1   | 880.7 MB  | #4         |  15%
# cudatoolkit-11.2.1   | 880.7 MB  | #4         |  15%
# cudatoolkit-11.2.1   | 880.7 MB  | #4         |  15%
# cudatoolkit-11.2.1   | 880.7 MB  | #4         |  15%
# cudatoolkit-11.2.1   | 880.7 MB  | #4         |  15%
# cudatoolkit-11.2.1   | 880.7 MB  | #4         |  15%
# cudatoolkit-11.2.1   | 880.7 MB  | #4         |  15%
# cudatoolkit-11.2.1   | 880.7 MB  | #4         |  15%
# cudatoolkit-11.2.1   | 880.7 MB  | #4         |  15%
# cudatoolkit-11.2.1   | 880.7 MB  | #4         |  15%
# cudatoolkit-11.2.1   | 880.7 MB  | #4         |  15%
# cudatoolkit-11.2.1   | 880.7 MB  | #4         |  15%
# cudatoolkit-11.2.1   | 880.7 MB  | #4         |  15%
# cudatoolkit-11.2.1   | 880.7 MB  | #5         |  15%
# cudatoolkit-11.2.1   | 880.7 MB  | #5         |  15%
# cudatoolkit-11.2.1   | 880.7 MB  | #5         |  15%
# cudatoolkit-11.2.1   | 880.7 MB  | #5         |  15%
# cudatoolkit-11.2.1   | 880.7 MB  | #5         |  15%
# cudatoolkit-11.2.1   | 880.7 MB  | #5         |  15%
# cudatoolkit-11.2.1   | 880.7 MB  | #5         |  15%
# cudatoolkit-11.2.1   | 880.7 MB  | #5         |  15%
# cudatoolkit-11.2.1   | 880.7 MB  | #5         |  15%
# cudatoolkit-11.2.1   | 880.7 MB  | #5         |  15%
# cudatoolkit-11.2.1   | 880.7 MB  | #5         |  15%
# cudatoolkit-11.2.1   | 880.7 MB  | #5         |  15%
# cudatoolkit-11.2.1   | 880.7 MB  | #5         |  15%
# cudatoolkit-11.2.1   | 880.7 MB  | #5         |  15%
# cudatoolkit-11.2.1   | 880.7 MB  | #5         |  15%
# cudatoolkit-11.2.1   | 880.7 MB  | #5         |  16%
# cudatoolkit-11.2.1   | 880.7 MB  | #5         |  16%
# cudatoolkit-11.2.1   | 880.7 MB  | #5         |  16%
# cudatoolkit-11.2.1   | 880.7 MB  | #5         |  16%
# cudatoolkit-11.2.1   | 880.7 MB  | #5         |  16%
# cudatoolkit-11.2.1   | 880.7 MB  | #5         |  16%
# cudatoolkit-11.2.1   | 880.7 MB  | #5         |  16%
# cudatoolkit-11.2.1   | 880.7 MB  | #5         |  16%
# cudatoolkit-11.2.1   | 880.7 MB  | #5         |  16%
# cudatoolkit-11.2.1   | 880.7 MB  | #5         |  16%
# cudatoolkit-11.2.1   | 880.7 MB  | #5         |  16%
# cudatoolkit-11.2.1   | 880.7 MB  | #5         |  16%
# cudatoolkit-11.2.1   | 880.7 MB  | #5         |  16%
# cudatoolkit-11.2.1   | 880.7 MB  | #5         |  16%
# cudatoolkit-11.2.1   | 880.7 MB  | #5         |  16%
# cudatoolkit-11.2.1   | 880.7 MB  | #5         |  16%
# cudatoolkit-11.2.1   | 880.7 MB  | #6         |  16%
# cudatoolkit-11.2.1   | 880.7 MB  | #6         |  16%
# cudatoolkit-11.2.1   | 880.7 MB  | #6         |  16%
# cudatoolkit-11.2.1   | 880.7 MB  | #6         |  16%
# cudatoolkit-11.2.1   | 880.7 MB  | #6         |  16%
# cudatoolkit-11.2.1   | 880.7 MB  | #6         |  16%
# cudatoolkit-11.2.1   | 880.7 MB  | #6         |  16%
# cudatoolkit-11.2.1   | 880.7 MB  | #6         |  16%
# cudatoolkit-11.2.1   | 880.7 MB  | #6         |  16%
# cudatoolkit-11.2.1   | 880.7 MB  | #6         |  16%
# cudatoolkit-11.2.1   | 880.7 MB  | #6         |  16%
# cudatoolkit-11.2.1   | 880.7 MB  | #6         |  16%
# cudatoolkit-11.2.1   | 880.7 MB  | #6         |  16%
# cudatoolkit-11.2.1   | 880.7 MB  | #6         |  16%
# cudatoolkit-11.2.1   | 880.7 MB  | #6         |  17%
# cudatoolkit-11.2.1   | 880.7 MB  | #6         |  17%
# cudatoolkit-11.2.1   | 880.7 MB  | #6         |  17%
# cudatoolkit-11.2.1   | 880.7 MB  | #6         |  17%
# cudatoolkit-11.2.1   | 880.7 MB  | #6         |  17%
# cudatoolkit-11.2.1   | 880.7 MB  | #6         |  17%
# cudatoolkit-11.2.1   | 880.7 MB  | #6         |  17%
# cudatoolkit-11.2.1   | 880.7 MB  | #6         |  17%
# cudatoolkit-11.2.1   | 880.7 MB  | #6         |  17%
# cudatoolkit-11.2.1   | 880.7 MB  | #6         |  17%
# cudatoolkit-11.2.1   | 880.7 MB  | #6         |  17%
# cudatoolkit-11.2.1   | 880.7 MB  | #6         |  17%
# cudatoolkit-11.2.1   | 880.7 MB  | #7         |  17%
# cudatoolkit-11.2.1   | 880.7 MB  | #7         |  17%
# cudatoolkit-11.2.1   | 880.7 MB  | #7         |  17%
# cudatoolkit-11.2.1   | 880.7 MB  | #7         |  17%
# cudatoolkit-11.2.1   | 880.7 MB  | #7         |  17%
# cudatoolkit-11.2.1   | 880.7 MB  | #7         |  17%
# cudatoolkit-11.2.1   | 880.7 MB  | #7         |  17%
# cudatoolkit-11.2.1   | 880.7 MB  | #7         |  17%
# cudatoolkit-11.2.1   | 880.7 MB  | #7         |  17%
# cudatoolkit-11.2.1   | 880.7 MB  | #7         |  17%
# cudatoolkit-11.2.1   | 880.7 MB  | #7         |  17%
# cudatoolkit-11.2.1   | 880.7 MB  | #7         |  17%
# cudatoolkit-11.2.1   | 880.7 MB  | #7         |  17%
# cudatoolkit-11.2.1   | 880.7 MB  | #7         |  17%
# cudatoolkit-11.2.1   | 880.7 MB  | #7         |  17%
# cudatoolkit-11.2.1   | 880.7 MB  | #7         |  18%
# cudatoolkit-11.2.1   | 880.7 MB  | #7         |  18%
# cudatoolkit-11.2.1   | 880.7 MB  | #7         |  18%
# cudatoolkit-11.2.1   | 880.7 MB  | #7         |  18%
# cudatoolkit-11.2.1   | 880.7 MB  | #7         |  18%
# cudatoolkit-11.2.1   | 880.7 MB  | #7         |  18%
# cudatoolkit-11.2.1   | 880.7 MB  | #7         |  18%
# cudatoolkit-11.2.1   | 880.7 MB  | #7         |  18%
# cudatoolkit-11.2.1   | 880.7 MB  | #7         |  18%
# cudatoolkit-11.2.1   | 880.7 MB  | #7         |  18%
# cudatoolkit-11.2.1   | 880.7 MB  | #7         |  18%
# cudatoolkit-11.2.1   | 880.7 MB  | #7         |  18%
# cudatoolkit-11.2.1   | 880.7 MB  | #7         |  18%
# cudatoolkit-11.2.1   | 880.7 MB  | #7         |  18%
# cudatoolkit-11.2.1   | 880.7 MB  | #7         |  18%
# cudatoolkit-11.2.1   | 880.7 MB  | #7         |  18%
# cudatoolkit-11.2.1   | 880.7 MB  | #8         |  18%
# cudatoolkit-11.2.1   | 880.7 MB  | #8         |  18%
# cudatoolkit-11.2.1   | 880.7 MB  | #8         |  18%
# cudatoolkit-11.2.1   | 880.7 MB  | #8         |  18%
# cudatoolkit-11.2.1   | 880.7 MB  | #8         |  18%
# cudatoolkit-11.2.1   | 880.7 MB  | #8         |  18%
# cudatoolkit-11.2.1   | 880.7 MB  | #8         |  18%
# cudatoolkit-11.2.1   | 880.7 MB  | #8         |  18%
# cudatoolkit-11.2.1   | 880.7 MB  | #8         |  18%
# cudatoolkit-11.2.1   | 880.7 MB  | #8         |  18%
# cudatoolkit-11.2.1   | 880.7 MB  | #8         |  18%
# cudatoolkit-11.2.1   | 880.7 MB  | #8         |  18%
# cudatoolkit-11.2.1   | 880.7 MB  | #8         |  18%
# cudatoolkit-11.2.1   | 880.7 MB  | #8         |  18%
# cudatoolkit-11.2.1   | 880.7 MB  | #8         |  18%
# cudatoolkit-11.2.1   | 880.7 MB  | #8         |  18%
# cudatoolkit-11.2.1   | 880.7 MB  | #8         |  19%
# cudatoolkit-11.2.1   | 880.7 MB  | #8         |  19%
# cudatoolkit-11.2.1   | 880.7 MB  | #8         |  19%
# cudatoolkit-11.2.1   | 880.7 MB  | #8         |  19%
# cudatoolkit-11.2.1   | 880.7 MB  | #8         |  19%
# cudatoolkit-11.2.1   | 880.7 MB  | #8         |  19%
# cudatoolkit-11.2.1   | 880.7 MB  | #8         |  19%
# cudatoolkit-11.2.1   | 880.7 MB  | #8         |  19%
# cudatoolkit-11.2.1   | 880.7 MB  | #8         |  19%
# cudatoolkit-11.2.1   | 880.7 MB  | #8         |  19%
# cudatoolkit-11.2.1   | 880.7 MB  | #8         |  19%
# cudatoolkit-11.2.1   | 880.7 MB  | #8         |  19%
# cudatoolkit-11.2.1   | 880.7 MB  | #8         |  19%
# cudatoolkit-11.2.1   | 880.7 MB  | #8         |  19%
# cudatoolkit-11.2.1   | 880.7 MB  | #8         |  19%
# cudatoolkit-11.2.1   | 880.7 MB  | #8         |  19%
# cudatoolkit-11.2.1   | 880.7 MB  | #8         |  19%
# cudatoolkit-11.2.1   | 880.7 MB  | #8         |  19%
# cudatoolkit-11.2.1   | 880.7 MB  | #8         |  19%
# cudatoolkit-11.2.1   | 880.7 MB  | #9         |  19%
# cudatoolkit-11.2.1   | 880.7 MB  | #9         |  19%
# cudatoolkit-11.2.1   | 880.7 MB  | #9         |  19%
# cudatoolkit-11.2.1   | 880.7 MB  | #9         |  19%
# cudatoolkit-11.2.1   | 880.7 MB  | #9         |  19%
# cudatoolkit-11.2.1   | 880.7 MB  | #9         |  19%
# cudatoolkit-11.2.1   | 880.7 MB  | #9         |  19%
# cudatoolkit-11.2.1   | 880.7 MB  | #9         |  19%
# cudatoolkit-11.2.1   | 880.7 MB  | #9         |  19%
# cudatoolkit-11.2.1   | 880.7 MB  | #9         |  19%
# cudatoolkit-11.2.1   | 880.7 MB  | #9         |  19%
# cudatoolkit-11.2.1   | 880.7 MB  | #9         |  19%
# cudatoolkit-11.2.1   | 880.7 MB  | #9         |  19%
# cudatoolkit-11.2.1   | 880.7 MB  | #9         |  19%
# cudatoolkit-11.2.1   | 880.7 MB  | #9         |  19%
# cudatoolkit-11.2.1   | 880.7 MB  | #9         |  19%
# cudatoolkit-11.2.1   | 880.7 MB  | #9         |  19%
# cudatoolkit-11.2.1   | 880.7 MB  | #9         |  20%
# cudatoolkit-11.2.1   | 880.7 MB  | #9         |  20%
# cudatoolkit-11.2.1   | 880.7 MB  | #9         |  20%
# cudatoolkit-11.2.1   | 880.7 MB  | #9         |  20%
# cudatoolkit-11.2.1   | 880.7 MB  | #9         |  20%
# cudatoolkit-11.2.1   | 880.7 MB  | #9         |  20%
# cudatoolkit-11.2.1   | 880.7 MB  | #9         |  20%
# cudatoolkit-11.2.1   | 880.7 MB  | #9         |  20%
# cudatoolkit-11.2.1   | 880.7 MB  | #9         |  20%
# cudatoolkit-11.2.1   | 880.7 MB  | #9         |  20%
# cudatoolkit-11.2.1   | 880.7 MB  | #9         |  20%
# cudatoolkit-11.2.1   | 880.7 MB  | #9         |  20%
# cudatoolkit-11.2.1   | 880.7 MB  | #9         |  20%
# cudatoolkit-11.2.1   | 880.7 MB  | #9         |  20%
# cudatoolkit-11.2.1   | 880.7 MB  | #9         |  20%
# cudatoolkit-11.2.1   | 880.7 MB  | #9         |  20%
# cudatoolkit-11.2.1   | 880.7 MB  | #9         |  20%
# cudatoolkit-11.2.1   | 880.7 MB  | #9         |  20%
# cudatoolkit-11.2.1   | 880.7 MB  | #9         |  20%
# cudatoolkit-11.2.1   | 880.7 MB  | #9         |  20%
# cudatoolkit-11.2.1   | 880.7 MB  | #9         |  20%
# cudatoolkit-11.2.1   | 880.7 MB  | #9         |  20%
# cudatoolkit-11.2.1   | 880.7 MB  | #9         |  20%
# cudatoolkit-11.2.1   | 880.7 MB  | ##         |  20%
# cudatoolkit-11.2.1   | 880.7 MB  | ##         |  20%
# cudatoolkit-11.2.1   | 880.7 MB  | ##         |  20%
# cudatoolkit-11.2.1   | 880.7 MB  | ##         |  20%
# cudatoolkit-11.2.1   | 880.7 MB  | ##         |  20%
# cudatoolkit-11.2.1   | 880.7 MB  | ##         |  20%
# cudatoolkit-11.2.1   | 880.7 MB  | ##         |  20%
# cudatoolkit-11.2.1   | 880.7 MB  | ##         |  20%
# cudatoolkit-11.2.1   | 880.7 MB  | ##         |  20%
# cudatoolkit-11.2.1   | 880.7 MB  | ##         |  20%
# cudatoolkit-11.2.1   | 880.7 MB  | ##         |  20%
# cudatoolkit-11.2.1   | 880.7 MB  | ##         |  20%
# cudatoolkit-11.2.1   | 880.7 MB  | ##         |  20%
# cudatoolkit-11.2.1   | 880.7 MB  | ##         |  20%
# cudatoolkit-11.2.1   | 880.7 MB  | ##         |  20%
# cudatoolkit-11.2.1   | 880.7 MB  | ##         |  20%
# cudatoolkit-11.2.1   | 880.7 MB  | ##         |  20%
# cudatoolkit-11.2.1   | 880.7 MB  | ##         |  20%
# cudatoolkit-11.2.1   | 880.7 MB  | ##         |  20%
# cudatoolkit-11.2.1   | 880.7 MB  | ##         |  20%
# cudatoolkit-11.2.1   | 880.7 MB  | ##         |  20%
# cudatoolkit-11.2.1   | 880.7 MB  | ##         |  20%
# cudatoolkit-11.2.1   | 880.7 MB  | ##         |  20%
# cudatoolkit-11.2.1   | 880.7 MB  | ##         |  20%
# cudatoolkit-11.2.1   | 880.7 MB  | ##         |  21%
# cudatoolkit-11.2.1   | 880.7 MB  | ##         |  21%
# cudatoolkit-11.2.1   | 880.7 MB  | ##         |  21%
# cudatoolkit-11.2.1   | 880.7 MB  | ##         |  21%
# cudatoolkit-11.2.1   | 880.7 MB  | ##         |  21%
# cudatoolkit-11.2.1   | 880.7 MB  | ##         |  21%
# cudatoolkit-11.2.1   | 880.7 MB  | ##         |  21%
# cudatoolkit-11.2.1   | 880.7 MB  | ##         |  21%
# cudatoolkit-11.2.1   | 880.7 MB  | ##         |  21%
# cudatoolkit-11.2.1   | 880.7 MB  | ##         |  21%
# cudatoolkit-11.2.1   | 880.7 MB  | ##         |  21%
# cudatoolkit-11.2.1   | 880.7 MB  | ##         |  21%
# cudatoolkit-11.2.1   | 880.7 MB  | ##         |  21%
# cudatoolkit-11.2.1   | 880.7 MB  | ##         |  21%
# cudatoolkit-11.2.1   | 880.7 MB  | ##         |  21%
# cudatoolkit-11.2.1   | 880.7 MB  | ##         |  21%
# cudatoolkit-11.2.1   | 880.7 MB  | ##         |  21%
# cudatoolkit-11.2.1   | 880.7 MB  | ##         |  21%
# cudatoolkit-11.2.1   | 880.7 MB  | ##         |  21%
# cudatoolkit-11.2.1   | 880.7 MB  | ##         |  21%
# cudatoolkit-11.2.1   | 880.7 MB  | ##         |  21%
# cudatoolkit-11.2.1   | 880.7 MB  | ##         |  21%
# cudatoolkit-11.2.1   | 880.7 MB  | ##1        |  21%
# cudatoolkit-11.2.1   | 880.7 MB  | ##1        |  21%
# cudatoolkit-11.2.1   | 880.7 MB  | ##1        |  21%
# cudatoolkit-11.2.1   | 880.7 MB  | ##1        |  21%
# cudatoolkit-11.2.1   | 880.7 MB  | ##1        |  21%
# cudatoolkit-11.2.1   | 880.7 MB  | ##1        |  21%
# cudatoolkit-11.2.1   | 880.7 MB  | ##1        |  21%
# cudatoolkit-11.2.1   | 880.7 MB  | ##1        |  21%
# cudatoolkit-11.2.1   | 880.7 MB  | ##1        |  21%
# cudatoolkit-11.2.1   | 880.7 MB  | ##1        |  21%
# cudatoolkit-11.2.1   | 880.7 MB  | ##1        |  21%
# cudatoolkit-11.2.1   | 880.7 MB  | ##1        |  21%
# cudatoolkit-11.2.1   | 880.7 MB  | ##1        |  21%
# cudatoolkit-11.2.1   | 880.7 MB  | ##1        |  21%
# cudatoolkit-11.2.1   | 880.7 MB  | ##1        |  21%
# cudatoolkit-11.2.1   | 880.7 MB  | ##1        |  21%
# cudatoolkit-11.2.1   | 880.7 MB  | ##1        |  21%
# cudatoolkit-11.2.1   | 880.7 MB  | ##1        |  21%
# cudatoolkit-11.2.1   | 880.7 MB  | ##1        |  21%
# cudatoolkit-11.2.1   | 880.7 MB  | ##1        |  21%
# cudatoolkit-11.2.1   | 880.7 MB  | ##1        |  21%
# cudatoolkit-11.2.1   | 880.7 MB  | ##1        |  21%
# cudatoolkit-11.2.1   | 880.7 MB  | ##1        |  22%
# cudatoolkit-11.2.1   | 880.7 MB  | ##1        |  22%
# cudatoolkit-11.2.1   | 880.7 MB  | ##1        |  22%
# cudatoolkit-11.2.1   | 880.7 MB  | ##1        |  22%
# cudatoolkit-11.2.1   | 880.7 MB  | ##1        |  22%
# cudatoolkit-11.2.1   | 880.7 MB  | ##1        |  22%
# cudatoolkit-11.2.1   | 880.7 MB  | ##1        |  22%
# cudatoolkit-11.2.1   | 880.7 MB  | ##1        |  22%
# cudatoolkit-11.2.1   | 880.7 MB  | ##1        |  22%
# cudatoolkit-11.2.1   | 880.7 MB  | ##1        |  22%
# cudatoolkit-11.2.1   | 880.7 MB  | ##1        |  22%
# cudatoolkit-11.2.1   | 880.7 MB  | ##1        |  22%
# cudatoolkit-11.2.1   | 880.7 MB  | ##1        |  22%
# cudatoolkit-11.2.1   | 880.7 MB  | ##1        |  22%
# cudatoolkit-11.2.1   | 880.7 MB  | ##1        |  22%
# cudatoolkit-11.2.1   | 880.7 MB  | ##1        |  22%
# cudatoolkit-11.2.1   | 880.7 MB  | ##2        |  22%
# cudatoolkit-11.2.1   | 880.7 MB  | ##2        |  22%
# cudatoolkit-11.2.1   | 880.7 MB  | ##2        |  22%
# cudatoolkit-11.2.1   | 880.7 MB  | ##2        |  22%
# cudatoolkit-11.2.1   | 880.7 MB  | ##2        |  22%
# cudatoolkit-11.2.1   | 880.7 MB  | ##2        |  22%
# cudatoolkit-11.2.1   | 880.7 MB  | ##2        |  22%
# cudatoolkit-11.2.1   | 880.7 MB  | ##2        |  22%
# cudatoolkit-11.2.1   | 880.7 MB  | ##2        |  22%
# cudatoolkit-11.2.1   | 880.7 MB  | ##2        |  22%
# cudatoolkit-11.2.1   | 880.7 MB  | ##2        |  22%
# cudatoolkit-11.2.1   | 880.7 MB  | ##2        |  22%
# cudatoolkit-11.2.1   | 880.7 MB  | ##2        |  22%
# cudatoolkit-11.2.1   | 880.7 MB  | ##2        |  22%
# cudatoolkit-11.2.1   | 880.7 MB  | ##2        |  22%
# cudatoolkit-11.2.1   | 880.7 MB  | ##2        |  22%
# cudatoolkit-11.2.1   | 880.7 MB  | ##2        |  23%
# cudatoolkit-11.2.1   | 880.7 MB  | ##2        |  23%
# cudatoolkit-11.2.1   | 880.7 MB  | ##2        |  23%
# cudatoolkit-11.2.1   | 880.7 MB  | ##2        |  23%
# cudatoolkit-11.2.1   | 880.7 MB  | ##2        |  23%
# cudatoolkit-11.2.1   | 880.7 MB  | ##2        |  23%
# cudatoolkit-11.2.1   | 880.7 MB  | ##2        |  23%
# cudatoolkit-11.2.1   | 880.7 MB  | ##2        |  23%
# cudatoolkit-11.2.1   | 880.7 MB  | ##2        |  23%
# cudatoolkit-11.2.1   | 880.7 MB  | ##2        |  23%
# cudatoolkit-11.2.1   | 880.7 MB  | ##2        |  23%
# cudatoolkit-11.2.1   | 880.7 MB  | ##2        |  23%
# cudatoolkit-11.2.1   | 880.7 MB  | ##2        |  23%
# cudatoolkit-11.2.1   | 880.7 MB  | ##2        |  23%
# cudatoolkit-11.2.1   | 880.7 MB  | ##2        |  23%
# cudatoolkit-11.2.1   | 880.7 MB  | ##2        |  23%
# cudatoolkit-11.2.1   | 880.7 MB  | ##2        |  23%
# cudatoolkit-11.2.1   | 880.7 MB  | ##2        |  23%
# cudatoolkit-11.2.1   | 880.7 MB  | ##2        |  23%
# cudatoolkit-11.2.1   | 880.7 MB  | ##2        |  23%
# cudatoolkit-11.2.1   | 880.7 MB  | ##2        |  23%
# cudatoolkit-11.2.1   | 880.7 MB  | ##3        |  23%
# cudatoolkit-11.2.1   | 880.7 MB  | ##3        |  23%
# cudatoolkit-11.2.1   | 880.7 MB  | ##3        |  23%
# cudatoolkit-11.2.1   | 880.7 MB  | ##3        |  23%
# cudatoolkit-11.2.1   | 880.7 MB  | ##3        |  23%
# cudatoolkit-11.2.1   | 880.7 MB  | ##3        |  23%
# cudatoolkit-11.2.1   | 880.7 MB  | ##3        |  23%
# cudatoolkit-11.2.1   | 880.7 MB  | ##3        |  23%
# cudatoolkit-11.2.1   | 880.7 MB  | ##3        |  23%
# ...
# cudatoolkit-11.2.1   | 880.7 MB  | #########2 |  93%
# cudatoolkit-11.2.1   | 880.7 MB  | #########2 |  93%
# cudatoolkit-11.2.1   | 880.7 MB  | #########2 |  93%
# cudatoolkit-11.2.1   | 880.7 MB  | #########2 |  93%
# cudatoolkit-11.2.1   | 880.7 MB  | #########2 |  93%
# cudatoolkit-11.2.1   | 880.7 MB  | #########2 |  93%
# cudatoolkit-11.2.1   | 880.7 MB  | #########2 |  93%
# cudatoolkit-11.2.1   | 880.7 MB  | #########2 |  93%
# cudatoolkit-11.2.1   | 880.7 MB  | #########2 |  93%
# cudatoolkit-11.2.1   | 880.7 MB  | #########2 |  93%
# cudatoolkit-11.2.1   | 880.7 MB  | #########2 |  93%
# cudatoolkit-11.2.1   | 880.7 MB  | #########2 |  93%
# cudatoolkit-11.2.1   | 880.7 MB  | #########2 |  93%
# cudatoolkit-11.2.1   | 880.7 MB  | #########2 |  93%
# cudatoolkit-11.2.1   | 880.7 MB  | #########2 |  93%
# cudatoolkit-11.2.1   | 880.7 MB  | #########3 |  93%
# cudatoolkit-11.2.1   | 880.7 MB  | #########3 |  93%
# cudatoolkit-11.2.1   | 880.7 MB  | #########3 |  93%
# cudatoolkit-11.2.1   | 880.7 MB  | #########3 |  93%
# cudatoolkit-11.2.1   | 880.7 MB  | #########3 |  93%
# cudatoolkit-11.2.1   | 880.7 MB  | #########3 |  93%
# cudatoolkit-11.2.1   | 880.7 MB  | #########3 |  93%
# cudatoolkit-11.2.1   | 880.7 MB  | #########3 |  93%
# cudatoolkit-11.2.1   | 880.7 MB  | #########3 |  93%
# cudatoolkit-11.2.1   | 880.7 MB  | #########3 |  93%
# cudatoolkit-11.2.1   | 880.7 MB  | #########3 |  93%
# cudatoolkit-11.2.1   | 880.7 MB  | #########3 |  93%
# cudatoolkit-11.2.1   | 880.7 MB  | #########3 |  93%
# cudatoolkit-11.2.1   | 880.7 MB  | #########3 |  93%
# cudatoolkit-11.2.1   | 880.7 MB  | #########3 |  93%
# cudatoolkit-11.2.1   | 880.7 MB  | #########3 |  93%
# cudatoolkit-11.2.1   | 880.7 MB  | #########3 |  93%
# cudatoolkit-11.2.1   | 880.7 MB  | #########3 |  93%
# cudatoolkit-11.2.1   | 880.7 MB  | #########3 |  93%
# cudatoolkit-11.2.1   | 880.7 MB  | #########3 |  93%
# cudatoolkit-11.2.1   | 880.7 MB  | #########3 |  93%
# cudatoolkit-11.2.1   | 880.7 MB  | #########3 |  93%
# cudatoolkit-11.2.1   | 880.7 MB  | #########3 |  94%
# cudatoolkit-11.2.1   | 880.7 MB  | #########3 |  94%
# cudatoolkit-11.2.1   | 880.7 MB  | #########3 |  94%
# cudatoolkit-11.2.1   | 880.7 MB  | #########3 |  94%
# cudatoolkit-11.2.1   | 880.7 MB  | #########3 |  94%
# cudatoolkit-11.2.1   | 880.7 MB  | #########3 |  94%
# cudatoolkit-11.2.1   | 880.7 MB  | #########3 |  94%
# cudatoolkit-11.2.1   | 880.7 MB  | #########3 |  94%
# cudatoolkit-11.2.1   | 880.7 MB  | #########3 |  94%
# cudatoolkit-11.2.1   | 880.7 MB  | #########3 |  94%
# cudatoolkit-11.2.1   | 880.7 MB  | #########3 |  94%
# cudatoolkit-11.2.1   | 880.7 MB  | #########3 |  94%
# cudatoolkit-11.2.1   | 880.7 MB  | #########3 |  94%
# cudatoolkit-11.2.1   | 880.7 MB  | #########3 |  94%
# cudatoolkit-11.2.1   | 880.7 MB  | #########3 |  94%
# cudatoolkit-11.2.1   | 880.7 MB  | #########3 |  94%
# cudatoolkit-11.2.1   | 880.7 MB  | #########3 |  94%
# cudatoolkit-11.2.1   | 880.7 MB  | #########3 |  94%
# cudatoolkit-11.2.1   | 880.7 MB  | #########3 |  94%
# cudatoolkit-11.2.1   | 880.7 MB  | #########3 |  94%
# cudatoolkit-11.2.1   | 880.7 MB  | #########4 |  94%
# cudatoolkit-11.2.1   | 880.7 MB  | #########4 |  94%
# cudatoolkit-11.2.1   | 880.7 MB  | #########4 |  94%
# cudatoolkit-11.2.1   | 880.7 MB  | #########4 |  94%
# cudatoolkit-11.2.1   | 880.7 MB  | #########4 |  94%
# cudatoolkit-11.2.1   | 880.7 MB  | #########4 |  94%
# cudatoolkit-11.2.1   | 880.7 MB  | #########4 |  94%
# cudatoolkit-11.2.1   | 880.7 MB  | #########4 |  94%
# cudatoolkit-11.2.1   | 880.7 MB  | #########4 |  94%
# cudatoolkit-11.2.1   | 880.7 MB  | #########4 |  94%
# cudatoolkit-11.2.1   | 880.7 MB  | #########4 |  94%
# cudatoolkit-11.2.1   | 880.7 MB  | #########4 |  94%
# cudatoolkit-11.2.1   | 880.7 MB  | #########4 |  94%
# cudatoolkit-11.2.1   | 880.7 MB  | #########4 |  94%
# cudatoolkit-11.2.1   | 880.7 MB  | #########4 |  94%
# cudatoolkit-11.2.1   | 880.7 MB  | #########4 |  94%
# cudatoolkit-11.2.1   | 880.7 MB  | #########4 |  94%
# cudatoolkit-11.2.1   | 880.7 MB  | #########4 |  94%
# cudatoolkit-11.2.1   | 880.7 MB  | #########4 |  94%
# cudatoolkit-11.2.1   | 880.7 MB  | #########4 |  94%
# cudatoolkit-11.2.1   | 880.7 MB  | #########4 |  95%
# cudatoolkit-11.2.1   | 880.7 MB  | #########4 |  95%
# cudatoolkit-11.2.1   | 880.7 MB  | #########4 |  95%
# cudatoolkit-11.2.1   | 880.7 MB  | #########4 |  95%
# cudatoolkit-11.2.1   | 880.7 MB  | #########4 |  95%
# cudatoolkit-11.2.1   | 880.7 MB  | #########4 |  95%
# cudatoolkit-11.2.1   | 880.7 MB  | #########4 |  95%
# cudatoolkit-11.2.1   | 880.7 MB  | #########4 |  95%
# cudatoolkit-11.2.1   | 880.7 MB  | #########4 |  95%
# cudatoolkit-11.2.1   | 880.7 MB  | #########4 |  95%
# cudatoolkit-11.2.1   | 880.7 MB  | #########4 |  95%
# cudatoolkit-11.2.1   | 880.7 MB  | #########4 |  95%
# cudatoolkit-11.2.1   | 880.7 MB  | #########4 |  95%
# cudatoolkit-11.2.1   | 880.7 MB  | #########4 |  95%
# cudatoolkit-11.2.1   | 880.7 MB  | #########4 |  95%
# cudatoolkit-11.2.1   | 880.7 MB  | #########4 |  95%
# cudatoolkit-11.2.1   | 880.7 MB  | #########4 |  95%
# cudatoolkit-11.2.1   | 880.7 MB  | #########4 |  95%
# cudatoolkit-11.2.1   | 880.7 MB  | #########4 |  95%
# cudatoolkit-11.2.1   | 880.7 MB  | #########4 |  95%
# cudatoolkit-11.2.1   | 880.7 MB  | #########5 |  95%
# cudatoolkit-11.2.1   | 880.7 MB  | #########5 |  95%
# cudatoolkit-11.2.1   | 880.7 MB  | #########5 |  95%
# cudatoolkit-11.2.1   | 880.7 MB  | #########5 |  95%
# cudatoolkit-11.2.1   | 880.7 MB  | #########5 |  95%
# cudatoolkit-11.2.1   | 880.7 MB  | #########5 |  95%
# cudatoolkit-11.2.1   | 880.7 MB  | #########5 |  95%
# cudatoolkit-11.2.1   | 880.7 MB  | #########5 |  95%
# cudatoolkit-11.2.1   | 880.7 MB  | #########5 |  95%
# cudatoolkit-11.2.1   | 880.7 MB  | #########5 |  95%
# cudatoolkit-11.2.1   | 880.7 MB  | #########5 |  95%
# cudatoolkit-11.2.1   | 880.7 MB  | #########5 |  95%
# cudatoolkit-11.2.1   | 880.7 MB  | #########5 |  95%
# cudatoolkit-11.2.1   | 880.7 MB  | #########5 |  95%
# cudatoolkit-11.2.1   | 880.7 MB  | #########5 |  95%
# cudatoolkit-11.2.1   | 880.7 MB  | #########5 |  95%
# cudatoolkit-11.2.1   | 880.7 MB  | #########5 |  95%
# cudatoolkit-11.2.1   | 880.7 MB  | #########5 |  95%
# cudatoolkit-11.2.1   | 880.7 MB  | #########5 |  95%
# cudatoolkit-11.2.1   | 880.7 MB  | #########5 |  95%
# cudatoolkit-11.2.1   | 880.7 MB  | #########5 |  96%
# cudatoolkit-11.2.1   | 880.7 MB  | #########5 |  96%
# cudatoolkit-11.2.1   | 880.7 MB  | #########5 |  96%
# cudatoolkit-11.2.1   | 880.7 MB  | #########5 |  96%
# cudatoolkit-11.2.1   | 880.7 MB  | #########5 |  96%
# cudatoolkit-11.2.1   | 880.7 MB  | #########5 |  96%
# cudatoolkit-11.2.1   | 880.7 MB  | #########5 |  96%
# cudatoolkit-11.2.1   | 880.7 MB  | #########5 |  96%
# cudatoolkit-11.2.1   | 880.7 MB  | #########5 |  96%
# cudatoolkit-11.2.1   | 880.7 MB  | #########5 |  96%
# cudatoolkit-11.2.1   | 880.7 MB  | #########5 |  96%
# cudatoolkit-11.2.1   | 880.7 MB  | #########5 |  96%
# cudatoolkit-11.2.1   | 880.7 MB  | #########5 |  96%
# cudatoolkit-11.2.1   | 880.7 MB  | #########5 |  96%
# cudatoolkit-11.2.1   | 880.7 MB  | #########5 |  96%
# cudatoolkit-11.2.1   | 880.7 MB  | #########5 |  96%
# cudatoolkit-11.2.1   | 880.7 MB  | #########5 |  96%
# cudatoolkit-11.2.1   | 880.7 MB  | #########5 |  96%
# cudatoolkit-11.2.1   | 880.7 MB  | #########5 |  96%
# cudatoolkit-11.2.1   | 880.7 MB  | #########5 |  96%
# cudatoolkit-11.2.1   | 880.7 MB  | #########5 |  96%
# cudatoolkit-11.2.1   | 880.7 MB  | #########5 |  96%
# cudatoolkit-11.2.1   | 880.7 MB  | #########6 |  96%
# cudatoolkit-11.2.1   | 880.7 MB  | #########6 |  96%
# cudatoolkit-11.2.1   | 880.7 MB  | #########6 |  96%
# cudatoolkit-11.2.1   | 880.7 MB  | #########6 |  96%
# cudatoolkit-11.2.1   | 880.7 MB  | #########6 |  96%
# cudatoolkit-11.2.1   | 880.7 MB  | #########6 |  96%
# cudatoolkit-11.2.1   | 880.7 MB  | #########6 |  96%
# cudatoolkit-11.2.1   | 880.7 MB  | #########6 |  96%
# cudatoolkit-11.2.1   | 880.7 MB  | #########6 |  96%
# cudatoolkit-11.2.1   | 880.7 MB  | #########6 |  96%
# cudatoolkit-11.2.1   | 880.7 MB  | #########6 |  96%
# cudatoolkit-11.2.1   | 880.7 MB  | #########6 |  96%
# cudatoolkit-11.2.1   | 880.7 MB  | #########6 |  96%
# cudatoolkit-11.2.1   | 880.7 MB  | #########6 |  96%
# cudatoolkit-11.2.1   | 880.7 MB  | #########6 |  96%
# cudatoolkit-11.2.1   | 880.7 MB  | #########6 |  96%
# cudatoolkit-11.2.1   | 880.7 MB  | #########6 |  96%
# cudatoolkit-11.2.1   | 880.7 MB  | #########6 |  96%
# cudatoolkit-11.2.1   | 880.7 MB  | #########6 |  96%
# cudatoolkit-11.2.1   | 880.7 MB  | #########6 |  96%
# cudatoolkit-11.2.1   | 880.7 MB  | #########6 |  97%
# cudatoolkit-11.2.1   | 880.7 MB  | #########6 |  97%
# cudatoolkit-11.2.1   | 880.7 MB  | #########6 |  97%
# cudatoolkit-11.2.1   | 880.7 MB  | #########6 |  97%
# cudatoolkit-11.2.1   | 880.7 MB  | #########6 |  97%
# cudatoolkit-11.2.1   | 880.7 MB  | #########6 |  97%
# cudatoolkit-11.2.1   | 880.7 MB  | #########6 |  97%
# cudatoolkit-11.2.1   | 880.7 MB  | #########6 |  97%
# cudatoolkit-11.2.1   | 880.7 MB  | #########6 |  97%
# cudatoolkit-11.2.1   | 880.7 MB  | #########6 |  97%
# cudatoolkit-11.2.1   | 880.7 MB  | #########6 |  97%
# cudatoolkit-11.2.1   | 880.7 MB  | #########6 |  97%
# cudatoolkit-11.2.1   | 880.7 MB  | #########6 |  97%
# cudatoolkit-11.2.1   | 880.7 MB  | #########6 |  97%
# cudatoolkit-11.2.1   | 880.7 MB  | #########6 |  97%
# cudatoolkit-11.2.1   | 880.7 MB  | #########6 |  97%
# cudatoolkit-11.2.1   | 880.7 MB  | #########7 |  97%
# cudatoolkit-11.2.1   | 880.7 MB  | #########7 |  97%
# cudatoolkit-11.2.1   | 880.7 MB  | #########7 |  97%
# cudatoolkit-11.2.1   | 880.7 MB  | #########7 |  97%
# cudatoolkit-11.2.1   | 880.7 MB  | #########7 |  97%
# cudatoolkit-11.2.1   | 880.7 MB  | #########7 |  97%
# cudatoolkit-11.2.1   | 880.7 MB  | #########7 |  97%
# cudatoolkit-11.2.1   | 880.7 MB  | #########7 |  97%
# cudatoolkit-11.2.1   | 880.7 MB  | #########7 |  97%
# cudatoolkit-11.2.1   | 880.7 MB  | #########7 |  97%
# cudatoolkit-11.2.1   | 880.7 MB  | #########7 |  97%
# cudatoolkit-11.2.1   | 880.7 MB  | #########7 |  97%
# cudatoolkit-11.2.1   | 880.7 MB  | #########7 |  97%
# cudatoolkit-11.2.1   | 880.7 MB  | #########7 |  97%
# cudatoolkit-11.2.1   | 880.7 MB  | #########7 |  97%
# cudatoolkit-11.2.1   | 880.7 MB  | #########7 |  97%
# cudatoolkit-11.2.1   | 880.7 MB  | #########7 |  97%
# cudatoolkit-11.2.1   | 880.7 MB  | #########7 |  97%
# cudatoolkit-11.2.1   | 880.7 MB  | #########7 |  98%
# cudatoolkit-11.2.1   | 880.7 MB  | #########7 |  98%
# cudatoolkit-11.2.1   | 880.7 MB  | #########7 |  98%
# cudatoolkit-11.2.1   | 880.7 MB  | #########7 |  98%
# cudatoolkit-11.2.1   | 880.7 MB  | #########7 |  98%
# cudatoolkit-11.2.1   | 880.7 MB  | #########7 |  98%
# cudatoolkit-11.2.1   | 880.7 MB  | #########7 |  98%
# cudatoolkit-11.2.1   | 880.7 MB  | #########7 |  98%
# cudatoolkit-11.2.1   | 880.7 MB  | #########7 |  98%
# cudatoolkit-11.2.1   | 880.7 MB  | #########7 |  98%
# cudatoolkit-11.2.1   | 880.7 MB  | #########7 |  98%
# cudatoolkit-11.2.1   | 880.7 MB  | #########7 |  98%
# cudatoolkit-11.2.1   | 880.7 MB  | #########7 |  98%
# cudatoolkit-11.2.1   | 880.7 MB  | #########7 |  98%
# cudatoolkit-11.2.1   | 880.7 MB  | #########7 |  98%
# cudatoolkit-11.2.1   | 880.7 MB  | #########7 |  98%
# cudatoolkit-11.2.1   | 880.7 MB  | #########7 |  98%
# cudatoolkit-11.2.1   | 880.7 MB  | #########7 |  98%
# cudatoolkit-11.2.1   | 880.7 MB  | #########7 |  98%
# cudatoolkit-11.2.1   | 880.7 MB  | #########8 |  98%
# cudatoolkit-11.2.1   | 880.7 MB  | #########8 |  98%
# cudatoolkit-11.2.1   | 880.7 MB  | #########8 |  98%
# cudatoolkit-11.2.1   | 880.7 MB  | #########8 |  98%
# cudatoolkit-11.2.1   | 880.7 MB  | #########8 |  98%
# cudatoolkit-11.2.1   | 880.7 MB  | #########8 |  98%
# cudatoolkit-11.2.1   | 880.7 MB  | #########8 |  98%
# cudatoolkit-11.2.1   | 880.7 MB  | #########8 |  98%
# cudatoolkit-11.2.1   | 880.7 MB  | #########8 |  98%
# cudatoolkit-11.2.1   | 880.7 MB  | #########8 |  98%
# cudatoolkit-11.2.1   | 880.7 MB  | #########8 |  98%
# cudatoolkit-11.2.1   | 880.7 MB  | #########8 |  98%
# cudatoolkit-11.2.1   | 880.7 MB  | #########8 |  98%
# cudatoolkit-11.2.1   | 880.7 MB  | #########8 |  98%
# cudatoolkit-11.2.1   | 880.7 MB  | #########8 |  98%
# cudatoolkit-11.2.1   | 880.7 MB  | #########8 |  98%
# cudatoolkit-11.2.1   | 880.7 MB  | #########8 |  98%
# cudatoolkit-11.2.1   | 880.7 MB  | #########8 |  98%
# cudatoolkit-11.2.1   | 880.7 MB  | #########8 |  99%
# cudatoolkit-11.2.1   | 880.7 MB  | #########8 |  99%
# cudatoolkit-11.2.1   | 880.7 MB  | #########8 |  99%
# cudatoolkit-11.2.1   | 880.7 MB  | #########8 |  99%
# cudatoolkit-11.2.1   | 880.7 MB  | #########8 |  99%
# cudatoolkit-11.2.1   | 880.7 MB  | #########8 |  99%
# cudatoolkit-11.2.1   | 880.7 MB  | #########8 |  99%
# cudatoolkit-11.2.1   | 880.7 MB  | #########8 |  99%
# cudatoolkit-11.2.1   | 880.7 MB  | #########8 |  99%
# cudatoolkit-11.2.1   | 880.7 MB  | #########8 |  99%
# cudatoolkit-11.2.1   | 880.7 MB  | #########8 |  99%
# cudatoolkit-11.2.1   | 880.7 MB  | #########8 |  99%
# cudatoolkit-11.2.1   | 880.7 MB  | #########8 |  99%
# cudatoolkit-11.2.1   | 880.7 MB  | #########8 |  99%
# cudatoolkit-11.2.1   | 880.7 MB  | #########8 |  99%
# cudatoolkit-11.2.1   | 880.7 MB  | #########8 |  99%
# cudatoolkit-11.2.1   | 880.7 MB  | #########8 |  99%
# cudatoolkit-11.2.1   | 880.7 MB  | #########8 |  99%
# cudatoolkit-11.2.1   | 880.7 MB  | #########8 |  99%
# cudatoolkit-11.2.1   | 880.7 MB  | #########8 |  99%
# cudatoolkit-11.2.1   | 880.7 MB  | #########8 |  99%
# cudatoolkit-11.2.1   | 880.7 MB  | #########8 |  99%
# cudatoolkit-11.2.1   | 880.7 MB  | #########9 |  99%
# cudatoolkit-11.2.1   | 880.7 MB  | #########9 |  99%
# cudatoolkit-11.2.1   | 880.7 MB  | #########9 |  99%
# cudatoolkit-11.2.1   | 880.7 MB  | #########9 |  99%
# cudatoolkit-11.2.1   | 880.7 MB  | #########9 |  99%
# cudatoolkit-11.2.1   | 880.7 MB  | #########9 |  99%
# cudatoolkit-11.2.1   | 880.7 MB  | #########9 |  99%
# cudatoolkit-11.2.1   | 880.7 MB  | #########9 |  99%
# cudatoolkit-11.2.1   | 880.7 MB  | #########9 |  99%
# cudatoolkit-11.2.1   | 880.7 MB  | #########9 |  99%
# cudatoolkit-11.2.1   | 880.7 MB  | #########9 |  99%
# cudatoolkit-11.2.1   | 880.7 MB  | #########9 |  99%
# cudatoolkit-11.2.1   | 880.7 MB  | #########9 |  99%
# cudatoolkit-11.2.1   | 880.7 MB  | #########9 |  99%
# cudatoolkit-11.2.1   | 880.7 MB  | #########9 |  99%
# cudatoolkit-11.2.1   | 880.7 MB  | #########9 |  99%
# cudatoolkit-11.2.1   | 880.7 MB  | #########9 |  99%
# cudatoolkit-11.2.1   | 880.7 MB  | #########9 |  99%
# cudatoolkit-11.2.1   | 880.7 MB  | #########9 |  99%
# cudatoolkit-11.2.1   | 880.7 MB  | #########9 |  99%
# cudatoolkit-11.2.1   | 880.7 MB  | #########9 |  99%
# cudatoolkit-11.2.1   | 880.7 MB  | #########9 |  99%
# cudatoolkit-11.2.1   | 880.7 MB  | #########9 |  99%
# cudatoolkit-11.2.1   | 880.7 MB  | #########9 | 100%
# cudatoolkit-11.2.1   | 880.7 MB  | #########9 | 100%
# cudatoolkit-11.2.1   | 880.7 MB  | #########9 | 100%
# cudatoolkit-11.2.1   | 880.7 MB  | #########9 | 100%
# cudatoolkit-11.2.1   | 880.7 MB  | #########9 | 100%
# cudatoolkit-11.2.1   | 880.7 MB  | #########9 | 100%
# cudatoolkit-11.2.1   | 880.7 MB  | #########9 | 100%
# cudatoolkit-11.2.1   | 880.7 MB  | #########9 | 100%
# cudatoolkit-11.2.1   | 880.7 MB  | #########9 | 100%
# cudatoolkit-11.2.1   | 880.7 MB  | #########9 | 100%
# cudatoolkit-11.2.1   | 880.7 MB  | #########9 | 100%
# cudatoolkit-11.2.1   | 880.7 MB  | #########9 | 100%
# cudatoolkit-11.2.1   | 880.7 MB  | #########9 | 100%
# cudatoolkit-11.2.1   | 880.7 MB  | #########9 | 100%
# cudatoolkit-11.2.1   | 880.7 MB  | #########9 | 100%
# cudatoolkit-11.2.1   | 880.7 MB  | #########9 | 100%
# cudatoolkit-11.2.1   | 880.7 MB  | #########9 | 100%
# cudatoolkit-11.2.1   | 880.7 MB  | #########9 | 100%
# cudatoolkit-11.2.1   | 880.7 MB  | #########9 | 100%
# cudatoolkit-11.2.1   | 880.7 MB  | #########9 | 100%
# cudatoolkit-11.2.1   | 880.7 MB  | ########## | 100%

# %%
from simtk.openmm.app import *
from simtk.openmm import *
from simtk.unit import *
from sys import stdout
import numpy as np
# %matplotlib notebook
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D
from tqdm import tqdm

# %%
pdb = PDBFile('proteins/6ct4.pdb')
forcefield = ForceField('amber14-all.xml', 'amber14/tip3pfb.xml')
modeller = Modeller(pdb.topology, pdb.positions)

system = forcefield.createSystem(modeller.topology, nonbondedMethod=CutoffNonPeriodic, nonbondedCutoff=1*nanometer, constraints=HBonds)
integrator = LangevinIntegrator(300*kelvin, 1/picosecond, 0.002*picoseconds)
simulation = Simulation(modeller.topology, system, integrator)
simulation.context.setPositions(modeller.positions)
simulation.minimizeEnergy()

# %%
class AA:
    def __init__(self, residue, context):
        self.context = context
        self.residue = residue
        self.atoms = list(self.residue.atoms())
        self.atoms_dict = {atom.name:atom.index for atom in self.atoms}
        self.atom_indices = list(self.atoms_dict.values())
        self.backbone_names = ['N', 'H', 'CA', 'HA', 'C', 'O', 'H2', 'H3', 'OXT']
        
    def _get_atom_pos(self):
        return self.context.getState(getPositions=True).getPositions(asNumpy=True)
    
    def get_atom_pos(self, positions=None):
        if positions is None:
            positions = self._get_atom_pos()
        return positions[self.atom_indices]
    
    def get_pos(self, positions=None):
        if positions is None:
            positions = self._get_atom_pos()
        return positions[self.atoms_dict['CA']]
        
    def get_backbone_dir(self, positions=None):
        if positions is None:
            positions = self._get_atom_pos()
        backbone_dir = positions[self.atoms_dict['C']] - positions[self.atoms_dict['N']]
        return backbone_dir / np.sqrt(np.sum(backbone_dir ** 2))
        
    def get_avg_side_chain_pos(self, positions=None):
        if positions is None:
            positions = self._get_atom_pos()
        indices = [atom.index for atom in self.atoms if atom.name not in self.backbone_names]
        return positions[indices].mean(axis=0)
    
    def get_side_chain_dir(self, positions=None):
        if positions is None:
            positions = self._get_atom_pos()
        side_chain_dir = self.get_avg_side_chain_pos(positions) - self.get_pos(positions)
        return side_chain_dir / np.sqrt(np.sum(side_chain_dir ** 2))
    
    def get_amino_pos(self, positions=None):
        if positions is None:
            positions = self._get_atom_pos()
        return positions[self.atoms_dict['N']]
    
    def get_carboxyl_pos(self, positions=None):
        if positions is None:
            positions = self._get_atom_pos()
        return positions[self.atoms_dict['C']]
    
    def set_pos(self, pos):
        positions = self._get_atom_pos()
        positions[self.atom_indices] += -self.get_pos(positions) + np.array(pos) * nanometers
        self.context.setPositions(positions)
            
chain = []
for i, residue in enumerate(simulation.topology.residues()):
    aa = AA(residue, simulation.context)
    chain.append(aa)

# %%
def plot(aas, all_atoms=False, side_chains=True, aa_connections=True, aa_backbones=True):
    def as_array(fun):
        return np.array([fun(aa)._value for aa in aas])
    
    fig = plt.figure(figsize=(9, 6))
    ax = fig.add_subplot(111, projection='3d')
    
    if all_atoms:
        positions = as_array(AA.get_atom_pos)
        for pos in positions:
            ax.plot(pos[:,0], pos[:,1], pos[:,2], '.', alpha=0.1)
    
    if side_chains:
        pos = as_array(AA.get_pos)
        side_chain_dir = as_array(AA.get_side_chain_dir) * 0.15
        ax.quiver(pos[:,0], pos[:,1], pos[:,2], side_chain_dir[:,0], side_chain_dir[:,1], side_chain_dir[:,2],
                  colors='black', alpha=0.35, linewidth=2)
    
    if aa_connections:
        for i in range(1, len(aas)):
            points = np.array([aas[i-1].get_carboxyl_pos()._value, aas[i].get_amino_pos()._value])
            ax.plot(points[:,0], points[:,1], points[:,2], c='black', alpha=0.4, linewidth=5)
    
    if aa_backbones:
        for aa in aas:
            points = np.array([aa.get_amino_pos()._value, aa.get_pos()._value, aa.get_carboxyl_pos()._value])
            ax.plot(points[:,0], points[:,1], points[:,2], linewidth=5)
    
    ax.axis('off')
    plt.tight_layout()
    plt.show()
    
plot(chain)
# Out:
# <img src="data:image/png;base64,..." width="900">
